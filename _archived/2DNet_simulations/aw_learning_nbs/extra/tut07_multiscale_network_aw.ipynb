# %% [markdown]
# # NetPyNE Tutorial 7: Multiscale Network

# %% [markdown]
# ## Preliminaries
#
# If you are going to run this notebook locally using Jupyter Notebook, start from following instructions https://github.com/Neurosim-lab/netpyne/blob/development/netpyne/tutorials/README.md.
#
# If you are using Open Source Brain or EBRAINS, everything is already set up.
#
# On any other online platform (e.g. on Google Collab) you might need to run the following commmands to install NEURON and NetPyNE using **pip**:
# ```
# !pip install neuron
# !pip install netpyne
# ```
#
# Now we are ready to start the tutorial.

# %% [markdown]
# ## Compile mechanisms
#
# The cell models require membrane mechanisms (e.g. channel models) that are not built-in to NEURON.  So, now we will compile the necessary mechanisms (in the `mod` directory) using `nrnivmodl`.  You can learn more about mechanisms and `.mod` files in the [NEURON documentation](https://www.neuron.yale.edu/neuron/static/py_doc/modelspec/programmatic/mechanisms/nmodl.html).

# %%
# !nrnivmodl mod
# Out:
# /home/adam/miniconda3/envs/mycondaenv/bin/nrnivmodl:10: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import working_set
# /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials
# Mod files: "mod/mod/A.mod" "mod/mod/AMPA.mod" "mod/mod/ar.mod" "mod/mod/beforestep_py.mod" "mod/mod/cadad.mod" "mod/mod/cad.mod" "mod/mod/cadyn.mod" "mod/mod/cagk.mod" "mod/mod/cal_mh.mod" "mod/mod/cal_mig.mod" "mod/mod/ca.mod" "mod/mod/canin.mod" "mod/mod/can_mig.mod" "mod/mod/catcb.mod" "mod/mod/cat_mig.mod" "mod/mod/cat.mod" "mod/mod/cat_traub.mod" "mod/mod/dipole.mod" "mod/mod/dipole_pp.mod" "mod/mod/ElectSyn.mod" "mod/mod/expsynstdp.mod" "mod/mod/GABAa.mod" "mod/mod/gabab.mod" "mod/mod/h_BS.mod" "mod/mod/HCN1.mod" "mod/mod/hh2.mod" "mod/mod/hh3.mod" "mod/mod/h_harnett.mod" "mod/mod/hin.mod" "mod/mod/h_kole.mod" "mod/mod/h_migliore.mod" "mod/mod/ican_sidi.mod" "mod/mod/IC.mod" "mod/mod/iholmw.mod" "mod/mod/IKsin.mod" "mod/mod/izhi2003a.mod" "mod/mod/izhi2003b.mod" "mod/mod/izhi2007a.mod" "mod/mod/izhi2007b.mod" "mod/mod/k2.mod" "mod/mod/kacurrent.mod" "mod/mod/kahp.mod" "mod/mod/ka.mod" "mod/mod/kap_BS.mod" "mod/mod/kapcb.mod" "mod/mod/kapin.mod" "mod/mod/kBK.mod" "mod/mod/kca.mod" "mod/mod/kc.mod" "mod/mod/kctin.mod" "mod/mod/kdmc_BS.mod" "mod/mod/kdr_BS.mod" "mod/mod/kdrcurrent.mod" "mod/mod/kdrin.mod" "mod/mod/km2.mod" "mod/mod/km.mod" "mod/mod/kv.mod" "mod/mod/lfp.mod" "mod/mod/mea.mod" "mod/mod/MyExp2SynBB.mod" "mod/mod/MyExp2SynNMDABB.mod" "mod/mod/nacurrent.mod" "mod/mod/naf.mod" "mod/mod/nafx.mod" "mod/mod/nap.mod" "mod/mod/nax_BS.mod" "mod/mod/naz.mod" "mod/mod/Nca.mod" "mod/mod/NMDA.mod" "mod/mod/OFThpo.mod" "mod/mod/OFThresh.mod" "mod/mod/savedist.mod" "mod/mod/vecevent.mod" "mod/mod/vecstim.mod"
#
# Creating 'x86_64' directory for .o files.
#
#  -> Compiling mod_func.cpp
#  -> NMODL ../mod/A.mod
#  -> NMODL ../mod/AMPA.mod
#  -> NMODL ../mod/ar.mod
# Translating ar.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/ar.c
# Translating AMPA.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/AMPA.c
# Translating A.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/A.c
# INCLUDEing netcon.inc
# INCLUDEing ofc.inc
# Thread Safe
# Thread Safe
# Thread Safe
#  -> NMODL ../mod/beforestep_py.mod
#  -> NMODL ../mod/cad.mod
#  -> NMODL ../mod/cadad.mod
# Translating beforestep_py.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/beforestep_py.c
# Notice: Use of POINTER is not thread safe.
# Notice: VERBATIM blocks are not thread safe
# Translating cad.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/cad.c
# Translating cadad.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/cadad.c
#  -> NMODL ../mod/cadyn.mod
# Thread Safe
# Thread Safe
#  -> NMODL ../mod/cagk.mod
#  -> NMODL ../mod/cal_mh.mod
# Translating cadyn.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/cadyn.c
# Thread Safe
# Translating cagk.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/cagk.c
#  -> NMODL ../mod/cal_mig.mod
# Translating cal_mh.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/cal_mh.c
# Thread Safe
# Thread Safe
#  -> NMODL ../mod/ca.mod
# Translating cal_mig.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/cal_mig.c
#  -> NMODL ../mod/canin.mod
# Warning: Default 2 of PARAMETER cao will be ignored and set by NEURON.
# Warning: Default 5e-05 of PARAMETER cai will be ignored and set by NEURON.
# Thread Safe
# Translating ca.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/ca.c
#  -> NMODL ../mod/can_mig.mod
# Translating canin.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/canin.c
# Notice: Assignment to the GLOBAL variable, "tadj", is not thread safe
# Thread Safe
#  -> NMODL ../mod/catcb.mod
#  -> NMODL ../mod/cat_mig.mod
# Translating can_mig.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/can_mig.c
# Warning: Default 2 of PARAMETER cao will be ignored and set by NEURON.
# Warning: Default 5e-05 of PARAMETER cai will be ignored and set by NEURON.
# Translating catcb.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/catcb.c
# Translating cat_mig.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/cat_mig.c
# Thread Safe
# Notice: Assignment to the GLOBAL variable, "hinf", is not thread safe
# Notice: Assignment to the GLOBAL variable, "minf", is not thread safe
#  -> NMODL ../mod/cat.mod
# Warning: Default 2 of PARAMETER cao will be ignored and set by NEURON.
# Warning: Default 5e-05 of PARAMETER cai will be ignored and set by NEURON.
# Warning: Default 25 of PARAMETER celsius will be ignored and set by NEURON.
# Thread Safe
#  -> NMODL ../mod/cat_traub.mod
#  -> NMODL ../mod/dipole.mod
# Translating cat.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/cat.c
# Translating cat_traub.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/cat_traub.c
# Thread Safe
# Thread Safe
# Translating dipole.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/dipole.c
#  -> NMODL ../mod/dipole_pp.mod
# Notice: Use of POINTER is not thread safe.
# Notice: Use of POINTER is not thread safe.
# Notice: Use of POINTER is not thread safe.
#  -> NMODL ../mod/ElectSyn.mod
#  -> NMODL ../mod/expsynstdp.mod
# Translating dipole_pp.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/dipole_pp.c
# Notice: Use of POINTER is not thread safe.
# Notice: Use of POINTER is not thread safe.
# Translating ElectSyn.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/ElectSyn.c
# Thread Safe
# Translating expsynstdp.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/expsynstdp.c
#  -> NMODL ../mod/GABAa.mod
#  -> NMODL ../mod/gabab.mod
# Thread Safe
#  -> NMODL ../mod/h_BS.mod
# Translating GABAa.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/GABAa.c
# Translating gabab.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/gabab.c
# INCLUDEing netcon.inc
# Notice: Assignment to the GLOBAL variable, "warn", is not thread safe
# Thread Safe
# Translating h_BS.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/h_BS.c
#  -> NMODL ../mod/HCN1.mod
#  -> NMODL ../mod/hh2.mod
# Warning: Default 34 of PARAMETER celsius will be ignored and set by NEURON.
# Thread Safe
#  -> NMODL ../mod/hh3.mod
# Translating hh2.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/hh2.c
# Translating HCN1.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/HCN1.c
# Translating hh3.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/hh3.c
# Notice: VERBATIM blocks are not thread safe
# Thread Safe
# Thread Safe
# Notice: This mechanism cannot be used with CVODE
# Warning: Default 37 of PARAMETER celsius will be ignored and set by NEURON.
# Warning: Default -80 of PARAMETER ek will be ignored and set by NEURON.
# Warning: Default 40 of PARAMETER ena will be ignored and set by NEURON.
#  -> NMODL ../mod/h_harnett.mod
#  -> NMODL ../mod/hin.mod
#  -> NMODL ../mod/h_kole.mod
# Translating h_harnett.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/h_harnett.c
# Translating hin.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/hin.c
# Translating h_kole.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/h_kole.c
# Thread Safe
# Warning: Default -10 of PARAMETER ehi will be ignored and set by NEURON.
# Thread Safe
#  -> NMODL ../mod/h_migliore.mod
# Thread Safe
#  -> NMODL ../mod/ican_sidi.mod
#  -> NMODL ../mod/IC.mod
# Translating h_migliore.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/h_migliore.c
# Translating ican_sidi.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/ican_sidi.c
# Translating IC.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/IC.c
# Thread Safe
# Warning: Default 36 of PARAMETER celsius will be ignored and set by NEURON.
#  -> NMODL ../mod/iholmw.mod
# Thread Safe
# Thread Safe
#  -> NMODL ../mod/IKsin.mod
#  -> NMODL ../mod/izhi2003a.mod
# Translating iholmw.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/iholmw.c
# INCLUDEing aux_fun.inc
# Translating IKsin.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/IKsin.c
# Thread Safe
# Translating izhi2003a.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/izhi2003a.c
# Thread Safe
#  -> NMODL ../mod/izhi2003b.mod
# Thread Safe
#  -> NMODL ../mod/izhi2007a.mod
#  -> NMODL ../mod/izhi2007b.mod
# Translating izhi2003b.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/izhi2003b.c
# Translating izhi2007a.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/izhi2007a.c
# Thread Safe
# Translating izhi2007b.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/izhi2007b.c
#  -> NMODL ../mod/k2.mod
# Notice: VERBATIM blocks are not thread safe
# Notice: VERBATIM blocks are not thread safe
#  -> NMODL ../mod/kacurrent.mod
# Translating k2.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/k2.c
#  -> NMODL ../mod/kahp.mod
# Thread Safe
#  -> NMODL ../mod/ka.mod
# Translating kacurrent.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/kacurrent.c
# Translating kahp.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/kahp.c
# Thread Safe
# Thread Safe
# Translating ka.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/ka.c
#  -> NMODL ../mod/kap_BS.mod
#  -> NMODL ../mod/kapcb.mod
# Thread Safe
# Translating kap_BS.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/kap_BS.c
# Translating kapcb.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/kapcb.c
#  -> NMODL ../mod/kapin.mod
# Thread Safe
# Thread Safe
#  -> NMODL ../mod/kBK.mod
# Translating kapin.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/kapin.c
#  -> NMODL ../mod/kca.mod
# Thread Safe
# Translating kBK.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/kBK.c
# Translating kca.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/kca.c
#  -> NMODL ../mod/kc.mod
# Notice: Assignment to the GLOBAL variable, "tadj", is not thread safe
# Thread Safe
#  -> NMODL ../mod/kctin.mod
#  -> NMODL ../mod/kdmc_BS.mod
# Translating kc.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/kc.c
# Thread Safe
# Translating kctin.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/kctin.c
# Translating kdmc_BS.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/kdmc_BS.c
#  -> NMODL ../mod/kdr_BS.mod
# NEURON's CVode method ignores conservation
# Thread Safe
# Thread Safe
#  -> NMODL ../mod/kdrcurrent.mod
# Translating kdr_BS.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/kdr_BS.c
#  -> NMODL ../mod/kdrin.mod
# Thread Safe
# Translating kdrcurrent.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/kdrcurrent.c
#  -> NMODL ../mod/km2.mod
# Translating kdrin.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/kdrin.c
# Thread Safe
# Thread Safe
#  -> NMODL ../mod/km.mod
# Translating km2.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/km2.c
#  -> NMODL ../mod/kv.mod
# Thread Safe
#  -> NMODL ../mod/lfp.mod
# Translating km.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/km.c
# Translating kv.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/kv.c
# Notice: Assignment to the GLOBAL variable, "ntau", is not thread safe
# Notice: Assignment to the GLOBAL variable, "ninf", is not thread safe
# Notice: Assignment to the GLOBAL variable, "tadj", is not thread safe
# Thread Safe
# Translating lfp.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/lfp.c
# Notice: Use of POINTER is not thread safe.
#  -> NMODL ../mod/mea.mod
#  -> NMODL ../mod/MyExp2SynBB.mod
#  -> NMODL ../mod/MyExp2SynNMDABB.mod
# Translating mea.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/mea.c
# Notice: Use of POINTER is not thread safe.
# Translating MyExp2SynBB.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/MyExp2SynBB.c
# Translating MyExp2SynNMDABB.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/MyExp2SynNMDABB.c
#  -> NMODL ../mod/nacurrent.mod
# Thread Safe
# Thread Safe
#  -> NMODL ../mod/naf.mod
#  -> NMODL ../mod/nafx.mod
# Translating nacurrent.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/nacurrent.c
# Translating naf.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/naf.c
# Thread Safe
# Translating nafx.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/nafx.c
#  -> NMODL ../mod/nap.mod
# Thread Safe
#  -> NMODL ../mod/nax_BS.mod
# Warning: Default 55 of PARAMETER ena will be ignored and set by NEURON.
# Thread Safe
#  -> NMODL ../mod/naz.mod
# Translating nap.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/nap.c
# Translating nax_BS.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/nax_BS.c
# Thread Safe
#  -> NMODL ../mod/Nca.mod
# Translating naz.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/naz.c
# Thread Safe
# Notice: Assignment to the GLOBAL variable, "htau", is not thread safe
# Notice: Assignment to the GLOBAL variable, "hinf", is not thread safe
# Notice: Assignment to the GLOBAL variable, "mtau", is not thread safe
# Notice: Assignment to the GLOBAL variable, "minf", is not thread safe
# Notice: Assignment to the GLOBAL variable, "tadj", is not thread safe
#  -> NMODL ../mod/NMDA.mod
# Translating Nca.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/Nca.c
#  -> NMODL ../mod/OFThpo.mod
# Notice: Assignment to the GLOBAL variable, "tadj", is not thread safe
# Translating NMDA.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/NMDA.c
# INCLUDEing netcon.inc
#  -> NMODL ../mod/OFThresh.mod
# Translating OFThpo.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/OFThpo.c
# Thread Safe
# Thread Safe
#  -> NMODL ../mod/savedist.mod
# Translating OFThresh.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/OFThresh.c
#  -> NMODL ../mod/vecevent.mod
# Thread Safe
# Translating savedist.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/savedist.c
# Thread Safe
#  -> NMODL ../mod/vecstim.mod
# Translating vecevent.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/vecevent.c
# Notice: ARTIFICIAL_CELL is a synonym for POINT_PROCESS which hints that it
# only affects and is affected by discrete events. As such it is not
# located in a section and is not associated with an integrator
# Thread Safe
#  -> Compiling A.c
#  -> Compiling AMPA.c
# Translating vecstim.mod into /mnt/disk15tb/adam/git_workspace/netpyne/netpyne/tutorials/x86_64/vecstim.c
# Thread Safe
#  -> Compiling ar.c
#  -> Compiling beforestep_py.c
#  -> Compiling cadad.c
#  -> Compiling cad.c
#  -> Compiling cadyn.c
#  -> Compiling cagk.c
#  -> Compiling cal_mh.c
#  -> Compiling cal_mig.c
#  -> Compiling ca.c
#  -> Compiling canin.c
#  -> Compiling can_mig.c
#  -> Compiling catcb.c
#  -> Compiling cat_mig.c
#  -> Compiling cat.c
#  -> Compiling cat_traub.c
#  -> Compiling dipole.c
#  -> Compiling dipole_pp.c
#  -> Compiling ElectSyn.c
#  -> Compiling expsynstdp.c
#  -> Compiling GABAa.c
#  -> Compiling gabab.c
#  -> Compiling h_BS.c
#  -> Compiling HCN1.c
#  -> Compiling hh2.c
#  -> Compiling hh3.c
#  -> Compiling h_harnett.c
#  -> Compiling hin.c
#  -> Compiling h_kole.c
#  -> Compiling h_migliore.c
#  -> Compiling ican_sidi.c
#  -> Compiling IC.c
#  -> Compiling iholmw.c
#  -> Compiling IKsin.c
#  -> Compiling izhi2003a.c
#  -> Compiling izhi2003b.c
#  -> Compiling izhi2007a.c
#  -> Compiling izhi2007b.c
#  -> Compiling k2.c
#  -> Compiling kacurrent.c
#  -> Compiling kahp.c
#  -> Compiling ka.c
#  -> Compiling kap_BS.c
#  -> Compiling kapcb.c
#  -> Compiling kapin.c
#  -> Compiling kBK.c
#  -> Compiling kca.c
#  -> Compiling kc.c
#  -> Compiling kctin.c
#  -> Compiling kdmc_BS.c
#  -> Compiling kdr_BS.c
#  -> Compiling kdrcurrent.c
#  -> Compiling kdrin.c
#  -> Compiling km2.c
#  -> Compiling km.c
#  -> Compiling kv.c
#  -> Compiling lfp.c
#  -> Compiling mea.c
#  -> Compiling MyExp2SynBB.c
#  -> Compiling MyExp2SynNMDABB.c
#  -> Compiling nacurrent.c
#  -> Compiling naf.c
#  -> Compiling nafx.c
#  -> Compiling nap.c
#  -> Compiling nax_BS.c
#  -> Compiling naz.c
#  -> Compiling Nca.c
#  -> Compiling NMDA.c
#  -> Compiling OFThpo.c
#  -> Compiling OFThresh.c
#  -> Compiling savedist.c
#  -> Compiling vecevent.c
#  -> Compiling vecstim.c
#  => LINKING shared library ./libnrnmech.so
#  => LINKING executable ./special LDFLAGS are:    -pthread
# Successfully created x86_64/special

# %%
from netpyne import specs, sim

# should go after importing netpyne
import matplotlib
# %matplotlib inline

#------------------------------------------------------------------------------
#
# NETWORK PARAMETERS
#
#------------------------------------------------------------------------------

netParams = specs.NetParams()  # object of class NetParams to store the network parameters

netParams.sizeX = 100 # x-dimension (horizontal length) size in um
netParams.sizeY = 500 # y-dimension (vertical height or cortical depth) size in um
netParams.sizeZ = 100 # z-dimension (horizontal length) size in um
netParams.propVelocity = 100.0 # propagation velocity (um/ms)
netParams.probLengthConst = 150.0 # length constant for conn probability (um)

#------------------------------------------------------------------------------
## Cell parameters
netParams.loadCellParams(label='E', fileName='cells/CSTR_cellParams.json')
netParams.importCellParams(label='I', fileName='cells/FScell.hoc', cellName='FScell')


#------------------------------------------------------------------------------
## Population parameters
netParams.popParams['E2'] = {'cellType': 'E', 'numCells': 10, 'yRange': [50,150]}
netParams.popParams['I2'] = {'cellType': 'I', 'numCells': 10, 'yRange': [50,150]}
netParams.popParams['E4'] = {'cellType': 'E', 'numCells': 10, 'yRange': [150,300]}
netParams.popParams['I4'] = {'cellType': 'I', 'numCells': 10, 'yRange': [150,300]}
netParams.popParams['E5'] = {'cellType': 'E', 'numCells': 10, 'ynormRange': [0.6,1.0]}
netParams.popParams['I5'] = {'cellType': 'I', 'numCells': 10, 'ynormRange': [0.6,1.0]}

#------------------------------------------------------------------------------
## Synaptic mechanism parameters
netParams.synMechParams['exc'] = {'mod': 'Exp2Syn', 'tau1': 0.8, 'tau2': 5.3, 'e': 0}  # NMDA synaptic mechanism
netParams.synMechParams['inh'] = {'mod': 'Exp2Syn', 'tau1': 0.6, 'tau2': 8.5, 'e': -75}  # GABA synaptic mechanism

#------------------------------------------------------------------------------
# Stimulation parameters
netParams.stimSourceParams['bkg'] = {'type': 'NetStim', 'rate': 20, 'noise': 0.3}
netParams.stimTargetParams['bkg->E'] = {'source': 'bkg', 'conds': {'cellType': ['E']}, 'weight': 0.02, 'sec': 'soma', 'delay': 'max(1, normal(5,2))', 'synMech': 'exc'}
netParams.stimTargetParams['bkg->I'] = {'source': 'bkg', 'conds': {'cellType': ['I']}, 'weight': 0.004, 'sec': 'soma', 'delay': 'max(1, normal(5,2))', 'synMech': 'exc'}

#------------------------------------------------------------------------------
# Cell connectivity rules
netParams.connParams['E->all'] = {
  'preConds': {'cellType': 'E'}, 
  'postConds': {'y': [50,500]},  #  E -> all (100-1000 um)
  'probability': 0.1,                  # probability of connection
  'weight': '0.04*post_ynorm',         # synaptic weight 
  'delay': 'dist_3D/propVelocity',      # transmission delay (ms) 
  'synMech': 'exc'}                     # synaptic mechanism 

netParams.connParams['I->E'] = {
  'preConds': {'cellType': 'I'}, 
  'postConds': {'pop': ['E2','E4','E5']},       #  I -> E
  'probability': '0.3*exp(-dist_3D/probLengthConst)',   # probability of connection
  'weight': 0.01,                                      # synaptic weight 
  'delay': 'dist_3D/propVelocity',                      # transmission delay (ms) 
  'sec': ['soma','Bdend'], 
  'synMech': 'inh'}                                     # synaptic mechanism 



#------------------------------------------------------------------------------
## RxD params

### constants

## Change ip3_init from 0 to 0.1 to observe multiscale effect:  
## netParams.rxdParams['constants']['ip3_init'] = 0.1
## high ip3 -> ER Ca released to Cyt -> kBK channels open -> less firing 

constants = {'ip3_init': 0.0,  # initial ip3 concentration 
            'caDiff': 0.08,  # calcium diffusion coefficient
            'ip3Diff': 1.41,  # ip3 diffusion coefficient
            'caci_init': 1e-5,  # intracellular calcium initial concentration
            'caco_init': 2.0,   # extracellular calcium initial concentration
            'gip3r': 12040 * 100,  # ip3 receptors density
            'gserca': 0.3913,  # SERCA conductance
            'gleak': 6.020,   # ER leak channel conductance
            'kserca': 0.1,  # SERCA reaction constant
            'kip3': 0.15,  # ip3 reaction constant
            'kact': 0.4,  #
            'ip3rtau': 2000,  # ip3 receptors time constant
            'fc': 0.8,  # fraction of cytosol
            'fe': 0.2,  # fraction of ER
            'margin': 20}  # extracellular volume additional margin 

netParams.rxdParams['constants'] = constants

### regions
regions = {}
regions['cyt'] = {'cells': 'all', 'secs': 'all', 'nrn_region': 'i', 'geometry': {'class': 'FractionalVolume', 'args': {'volume_fraction': constants['fc'], 'surface_fraction': 1}}}
regions['er'] = {'cells': 'all', 'secs': 'all', 'geometry': {'class': 'FractionalVolume', 'args': {'volume_fraction': constants['fe']}}}
regions['cyt_er_membrane'] = {'cells': 'all', 'secs': 'all', 'geometry': {'class': 'ScalableBorder', 'args': {'scale': 1, 'on_cell_surface': False}}}

margin = 20  # extracellular volume additional margin 
x, y, z = [0-margin, 100+margin], [-500-margin, 0+margin], [0-margin, 100+margin]
regions['ecs'] = {'extracellular': True, 'xlo': x[0], 'ylo': y[0], 'zlo': z[0], 'xhi': x[1], 'yhi': y[1], 'zhi': z[1], 'dx': 5, 'volume_fraction': 0.2, 'tortuosity': 1.6} 

netParams.rxdParams['regions'] = regions

### species 
species = {}
species['ca'] = {'regions': ['cyt', 'er', 'ecs'], 'd': constants['caDiff'], 'charge': 2,
                'initial': 'caco_init if isinstance(node,rxd.node.NodeExtracellular) else (0.0017 - caci_init * fc) / fe if node.region == er else caci_init'}
species['ip3'] = {'regions': ['cyt'], 'd': constants['ip3Diff'], 'initial': constants['ip3_init']}
netParams.rxdParams['species'] = species

### states
netParams.rxdParams['states'] = {'ip3r_gate_state': {'regions': ['cyt_er_membrane'], 'initial': 0.8}}

### reactions
minf = 'ip3[cyt] * 1000. * ca[cyt] / (ip3[cyt] + kip3) / (1000. * ca[cyt] + kact)'
h_gate = 'ip3r_gate_state[cyt_er_membrane]'
kip3 = 'gip3r * (%s * %s) ** 3' % (minf, h_gate)

mcReactions = {}
mcReactions['serca'] = {'reactant': 'ca[cyt]', 'product': 'ca[er]', 'rate_f': 'gserca / ((kserca / (1000. * ca[cyt])) ** 2 + 1)', 'membrane': 'cyt_er_membrane', 'custom_dynamics': True}
mcReactions['leak'] = {'reactant': 'ca[er]', 'product': 'ca[cyt]', 'rate_f': constants['gleak'], 'rate_b': constants['gleak'], 'membrane': 'cyt_er_membrane'}
mcReactions['ip3r'] = {'reactant': 'ca[er]', 'product': 'ca[cyt]', 'rate_f': kip3, 'rate_b': kip3, 'membrane': 'cyt_er_membrane'}
netParams.rxdParams['multicompartmentReactions'] = mcReactions

### rates
netParams.rxdParams['rates'] = {'ip3rg': {'species': h_gate, 'rate': '(1. / (1 + 1000. * ca[cyt] / (0.3)) - %s) / ip3rtau'%(h_gate)}}




#------------------------------------------------------------------------------
#
# SIMULATION CONFIGURATION
#
#------------------------------------------------------------------------------

# Run parameters
simConfig = specs.SimConfig()       # object of class simConfig to store simulation configuration
simConfig.duration = 1.0*1e3        # Duration of the simulation, in ms
simConfig.hParams['v_init'] = -65   # set v_init to -65 mV
simConfig.dt = 0.1                  # Internal integration timestep to use
simConfig.verbose = False            # Show detailed messages 
simConfig.recordStep = 1             # Step size in ms to save data (eg. V traces, LFP, etc)
simConfig.filename = 'rxd_net'   # Set file output name


# Recording/plotting parameters
simConfig.recordTraces = {'V_soma':{'sec': 'soma','loc': 0.5,'var': 'v'},
                          'ik_soma': {'sec': 'soma', 'loc': 0.5, 'var': 'ik'},
                          'cai_soma': {'sec': 'soma', 'loc':0.5, 'var': 'cai'},
                          'cao_soma': {'sec': 'soma', 'loc': 0.5, 'var': 'cao'}}

simConfig.recordLFP = [[-15, y, 1.0*netParams.sizeZ] for y in range(int(netParams.sizeY/3), int(netParams.sizeY), int(netParams.sizeY/3))]
simConfig.recordDipole = True

simConfig.analysis['plotTraces'] ={'include': [0]}
simConfig.analysis['plotRaster'] = {'orderBy': 'y', 'orderInverse': True, 'saveFig': True, 'figSize': (9,3)}      # Plot a raster
simConfig.analysis['plotLFP'] = {'includeAxon': False, 'figSize': (6,10), 'saveFig': True} 
simConfig.analysis['plotRxDConcentration'] = {'speciesLabel': 'ca', 'regionLabel': 'ecs'}


#from netpyne import sim
sim.createSimulateAnalyze(netParams, simConfig)
# Out:
# Start time:  2024-02-22 00:10:09.834647
#
# Creating network of 6 cell populations on 1 hosts...
#   Number of cells on node 0: 60
#   Done; cell creation time = 0.03 s.
# Making connections...
#   Number of connections on node 0: 309
#   Done; cell connection time = 0.04 s.
# Adding stims...
#   Number of stims on node 0: 60
#   Done; cell stims creation time = 0.01 s.
# Adding RxD...
#   Created Region cyt
#   Created Region er
#   Created Region cyt_er_membrane
#   Created Extracellular Region ecs
#   Created Species ca
#   Created Species ip3
#   Created State ip3r_gate_state
#   Created MultiCompartmentReaction serca
#   Created MultiCompartmentReaction leak
#   Created MultiCompartmentReaction ip3r
#   Created Rate ip3rg
#   Done; RxD setup time = 0.01 s.
# Recording 4 traces of 4 types on node 0
#
# Running simulation using NEURON for 1000.0 ms...
#   Done; run time = 45.54 s; real-time ratio: 0.02.
#
# Gathering data...
#   Done; gather time = 0.03 s.
#
# Analyzing...
#   Cells: 60
#   Connections: 369 (6.15 per cell)
#   Spikes: 1503 (25.05 Hz)
#   Simulated time: 1.0 s; 1 workers
#   Run time: 45.54 s
# Warning: data won't be saved. No output format specified (consider sim.cfg.savePickle, sim.cfg.saveJson etc.)
# Plotting recorded cell traces ... cell
# Preparing spike data...
# Plotting raster...
# Preparing LFP data...
# Plotting LFP time series...
# Preparing LFP data...
# Preparing PSD data...
# Plotting LFP power spectral density (PSD)...
# Preparing LFP data...
# Preparing spectrogram data...
# Plotting LFP spectrogram...
# Plotting LFP electrode locations...
# Plotting 3D cell shape ...
# Plotting RxD concentration ...
#   min: 1.9958068009150318
#   max: 2.000000000000529
#   Done; plotting time = 5.93 s
#
# Total time = 53.51 s

# %%
sim.plotting.plotLFPTimeSeries()
# Out:
# Preparing LFP data...
# Plotting LFP time series...

# %%
sim.plotting.plotLFPSpectrogram(electrodes=['avg'])
# Out:
# Preparing LFP data...
# Preparing spectrogram data...
# Plotting LFP spectrogram...

# %%
sim.analysis.plotDipole()

# %%
# !pip install h5py
sim.analysis.plotEEG()
# Out:
# Requirement already satisfied: h5py in /home/adam/miniconda3/envs/mycondaenv/lib/python3.11/site-packages (3.9.0)
# Requirement already satisfied: numpy>=1.17.3 in /home/adam/miniconda3/envs/mycondaenv/lib/python3.11/site-packages (from h5py) (1.24.0)
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[6], line 2
#       1 get_ipython().system('pip install h5py')
# ----> 2 sim.analysis.plotEEG()
#
# File ~/miniconda3/envs/mycondaenv/lib/python3.11/site-packages/netpyne/analysis/dipole.py:97, in plotEEG(showCell, showPop, timeRange, dipole_location, dpi, figSize, showFig, saveFig)
#      93 from .. import sim
#      95 from lfpykit.eegmegcalc import NYHeadModel
# ---> 97 nyhead = NYHeadModel(nyhead_file=os.getenv('NP_LFPYKIT_HEAD_FILE', None))
#      99 # dipole_location = 'parietal_lobe'  # predefined location from NYHead class
#     100 nyhead.set_dipole_pos(dipole_location)
#
# File ~/miniconda3/envs/mycondaenv/lib/python3.11/site-packages/lfpykit/eegmegcalc.py:1391, in NYHeadModel.__init__(self, nyhead_file)
#    1383 # Some example locations in NY Head model
#    1384 self.dipole_pos_dict = {
#    1385     'calcarine_sulcus': np.array([5, -86, 2]),
#    1386     'motorsensory_cortex': np.array([18, 8, 71]),
#    1387     'parietal_lobe': np.array([54, -48, 55.9]),
#    1388     'occipital_lobe': np.array([-24.7, -103.3, -1.46])
#    1389 }
# -> 1391 self._load_head_model(nyhead_file)
#    1393 # These will be set by the "set_dipole_pos" function:
#    1394 self.dipole_pos = None
#
# File ~/miniconda3/envs/mycondaenv/lib/python3.11/site-packages/lfpykit/eegmegcalc.py:1435, in NYHeadModel._load_head_model(self, nyhead_file)
#    1432         print("Unable to find or download New York head model file")
#    1433         raise
# -> 1435 self.head_data = h5py.File(self.head_file, 'r')["sa"]
#    1436 self.cortex = np.array(self.head_data["cortex75K"]["vc"])
#    1437 self.lead_field = np.array(self.head_data["cortex75K"]["V_fem"])
#
# File ~/miniconda3/envs/mycondaenv/lib/python3.11/site-packages/h5py/_hl/files.py:567, in File.__init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, meta_block_size, **kwds)
#     558     fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0,
#     559                      locking, page_buf_size, min_meta_keep, min_raw_keep,
#     560                      alignment_threshold=alignment_threshold,
#     561                      alignment_interval=alignment_interval,
#     562                      meta_block_size=meta_block_size,
#     563                      **kwds)
#     564     fcpl = make_fcpl(track_order=track_order, fs_strategy=fs_strategy,
#     565                      fs_persist=fs_persist, fs_threshold=fs_threshold,
#     566                      fs_page_size=fs_page_size)
# --> 567     fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#     569 if isinstance(libver, tuple):
#     570     self._libver = libver
#
# File ~/miniconda3/envs/mycondaenv/lib/python3.11/site-packages/h5py/_hl/files.py:231, in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     229     if swmr and swmr_support:
#     230         flags |= h5f.ACC_SWMR_READ
# --> 231     fid = h5f.open(name, flags, fapl=fapl)
#     232 elif mode == 'r+':
#     233     fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5f.pyx:106, in h5py.h5f.open()
#
# OSError: Unable to open file (file signature not found)

# %% [markdown]
# Try changing the 'ip3_init' concentration to 0.1 and checking the effect it has on LFP and EEG.
#
# This demonstrates the effects of changes at the molecular scale affect the cellular and circuit scales, and are reflected in large-scale recording modalities (LFP, EEG).

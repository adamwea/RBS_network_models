# %%
import netpyne # idk why, but importing netpyne here makes the matplotlib inline work
# Out:
# ...
# --No graphics will be displayed.

# %%
# %matplotlib inline
import sys
sys.path.append('/home/adamm/workspace/network_simulations/')
from NERSC.plotting_functions import plot_experimental_raster
from NERSC import USER_INPUTS
#load npz file
data_path='/home/adamm/workspace/network_simulations/experimental_data/KCNT1/wt/spike_array_uncompressed.npz'
save_fig = 'figures/June2024/KCNT1_wt_raster.png'
#save_fig = 'figures/June2024/KCNT1_wt_raster.svg'
figsize = (10, 5)
raster_fig = plot_experimental_raster(data_path, save_fig = save_fig, sampling_rate=10000, xlim_start=30, xlim_end=300, figsize = figsize) #spec xlim in seconds
#raster_fig.show()
print('Raster plot saved as:', save_fig)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 4
#       2 import sys
#       3 sys.path.append('/home/adamm/workspace/network_simulations/')
# ----> 4 from NERSC.plotting_functions import plot_experimental_raster
#       5 from NERSC import USER_INPUTS
#       6 #load npz file
#
# File ~/workspace/network_simulations/NERSC/plotting_functions.py:1
# ----> 1 from USER_INPUTS import *
#       2 import numpy as np
#       3 from matplotlib import pyplot as plt
#
# ModuleNotFoundError: No module named 'USER_INPUTS'

# %%
#simulation raster plot
# %matplotlib inline
import sys
sys.path.append('./NERSC')
from NERSC.plotting_functions import plot_sim_raster
#load npz file
data_path='experimental_data/KCNT1/wt/spike_array_uncompressed.npz'
save_fig = 'figures/June2024/KCNT1_wt_raster.png'
#save_fig = 'figures/June2024/KCNT1_wt_raster.svg'
figsize = (10, 5)
raster_fig = plot_experimental_raster(data_path, save_fig = save_fig, sampling_rate=10000, xlim_start=30, xlim_end=300, figsize = figsize) #spec xlim in seconds
#raster_fig.show()
print('Raster plot saved as:', save_fig)

# %%
# %matplotlib inline
import sys
sys.path.append('./NERSC')
from NERSC.plotting_functions import plot_experimental_network_activity
#load npz file
npz_file_path='experimental_data/KCNT1/wt/spike_array_uncompressed.npz'
xlsx_file_path='experimental_data/KCNT1/wt/quality_metrics.xlsx'
save_fig = 'figures/June2024/KCNT1_wt_network_activity.png'
#save_fig = 'figures/June2024/KCNT1_wt_network_activity.svg'
xlim = (30, 300) #spec xlim in seconds
ylim = None
figsize = (10, 5)
conv_params = {
    'binSize': .1,
    'gaussianSigma': .15,
    'thresholdBurst': 1.5,
    'min_peak_distance': 1, #sec
    }
net_fig = plot_experimental_network_activity(npz_file_path, xlsx_file_path, save_fig=save_fig, ylim=ylim, xlim=xlim, figsize=figsize, conv_params=conv_params)
#net_fig.show()
print('Network activity plot saved as:', save_fig)#
# Out:
# Network activity plot saved as: figures/June2024/KCNT1_wt_network_activity.png

# %%
#simulation raster plot

# %%
#fitness circle

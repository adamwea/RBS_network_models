# %% [markdown]
# # NetPyNE Tutorial 9: Evolutionary Algorithm for Parameters Optimization

# %%
# !pip install inspyred
# Out:
# Requirement already satisfied: inspyred in /home/adam/miniconda3/envs/mycondaenv/lib/python3.11/site-packages (1.0.2)
# Requirement already satisfied: Click>=6.0 in /home/adam/miniconda3/envs/mycondaenv/lib/python3.11/site-packages (from inspyred) (8.1.6)
# Requirement already satisfied: numpy in /home/adam/miniconda3/envs/mycondaenv/lib/python3.11/site-packages (from inspyred) (1.26.4)

# %%
import os
# if not os.path.exists('nb2_files/batch_evol'):
#     os.makedirs('nb2_files/batch_evol')
os.chdir(os.getcwd() + '/nb2_files/batch_evol')
print(os.getcwd())
# Out:
# /mnt/disk15tb/adam/git_workspace/netpyne/hdmea_simulations/BurstingPlotDevelopment/nb2_files/batch_evol

# %% [markdown]
# Two examples are provided: 'simple' and 'complex'.
# In 'simple', 3 parameters are optimized to match target firing rates in 2 populations.
# In 'complex', 6 parameters are optimized to match target firing rates in 6 populations.
#
# First we import all necessary modules, and then describe parameters space to explore.

# %%
# %matplotlib inline
from netpyne import specs
from netpyne.batch import Batch

params = specs.ODict()
params['probEall'] = [0.05, 0.2] # 0.1
params['weightEall'] = [0.0025, 0.0075] #5.0
params['probIE'] = [0.2, 0.6] #0.4
params['weightIE'] = [0.0005, 0.002]
params['probLengthConst'] = [100,200]
params['stimWeight'] = [0.05, 0.2]

pops = {}
pops['E2'] = {'target': 5, 'width': 2, 'min': 1}
pops['I2'] = {'target': 10, 'width': 5, 'min': 2}
pops['E4'] = {'target': 30, 'width': 10, 'min': 1}
pops['I4'] = {'target': 10, 'width': 3, 'min': 2}
pops['E5'] = {'target': 40, 'width': 4, 'min': 1}
pops['I5'] = {'target': 25, 'width': 5, 'min': 2}

# %% [markdown]
# Provide fitness function and it's arguments:

# %%
fitnessFuncArgs = {}
fitnessFuncArgs['pops'] = pops
fitnessFuncArgs['maxFitness'] = 1000

def fitnessFunc(simData, **kwargs):
    import numpy as np
    pops = kwargs['pops']
    maxFitness = kwargs['maxFitness']
    popFitness = [None for i in pops.items()]
    popFitness = [min(np.exp(  abs(v['target'] - simData['popRates'][k])  /  v['width']), maxFitness)
            if simData["popRates"][k]>v['min'] else maxFitness for k,v in pops.items()]
    fitness = np.mean(popFitness)
    popInfo = '; '.join(['%s rate=%.1f fit=%1.f'%(p,r,f) for p,r,f in zip(list(simData['popRates'].keys()), list(simData['popRates'].values()), popFitness)])
    print('  '+popInfo)
    return fitness

# %% [markdown]
# Here we create `Batch` object with paramaters to tune, and set output folder, optimization method ('evol'), fitness function and all the configurations from above.

# %%
batch = Batch(params=params)

# Set output folder, grid method (all param combinations), and run configuration
batch.batchLabel = 'complex'
batch.saveFolder = './' + batch.batchLabel
batch.method = 'evol'
batch.runCfg = {
	'type': 'mpi_bulletin',#'hpc_slurm',
	'script': 'init.py',
	# options required only for hpc
	'mpiCommand': 'mpirun',
	'nodes': 1,
	'coresPerNode': 2,
	'allocation': 'default',
	'email': 'amwe@ucdavis.edu',
	'reservation': None,
	#'folder': '/home/salvadord/evol'
	#'custom': 'export LD_LIBRARY_PATH="$HOME/.openmpi/lib"' # only for conda users
}
batch.evolCfg = {
	'evolAlgorithm': 'custom',
	'fitnessFunc': fitnessFunc, # fitness expression (should read simData)
	'fitnessFuncArgs': fitnessFuncArgs,
	'pop_size': 6,
	'num_elites': 1, # keep this number of parents for next generation if they are fitter than children
	'mutation_rate': 0.4,
	'crossover': 0.5,
	'maximize': False, # maximize fitness function?
	'max_generations': 4,
	'time_sleep': 5, # wait this time before checking again if sim is completed (for each generation)
	'maxiter_wait': 40, # max number of times to check if sim is completed (for each generation)
	'defaultFitness': 1000 # set fitness value in case simulation time is over
}

# %% [markdown]
# Now we can run this code. When completed, you can inspect folder `tut_batch_evol/{networkType}`, where `{networkType}` is either `simple` or `complex`, to find the output of each generation and the summary for all, including the optimal values of requested parameters (short summary will also appear in the output of the cell).
#
# Note that the algorithm is stochastic, so you will not get the same results if re-run it again.

# %%
batch.run()
# Out:
# Saving batch to ./complex/complex_batch.json ...
# ['probEall', 'weightEall', 'probIE', 'weightIE', 'probLengthConst', 'stimWeight'] [0.12962380919275168, 0.0064387127763064385, 0.5352322758834878, 0.0012324885065375774, 148.9491237916065, 0.15995889134204477]
# set probEall=0.12962380919275168
# set weightEall=0.0064387127763064385
# set probIE=0.5352322758834878
# set weightIE=0.0012324885065375774
# set probLengthConst=148.9491237916065
# set stimWeight=0.15995889134204477
# Saving simConfig to ./complex/gen_0/gen_0_cand_0_cfg.json ...
# --------------------------------------------------------------------------------
# ['probEall', 'weightEall', 'probIE', 'weightIE', 'probLengthConst', 'stimWeight'] [0.14073352009734763, 0.003692229763531849, 0.4686334154946002, 0.000728383830027002, 197.34190214408324, 0.061331777157537286]
# set probEall=0.14073352009734763
# set weightEall=0.003692229763531849
# set probIE=0.4686334154946002
# set weightIE=0.000728383830027002
# set probLengthConst=197.34190214408324
# set stimWeight=0.061331777157537286
# Saving simConfig to ./complex/gen_0/gen_0_cand_1_cfg.json ...
# --------------------------------------------------------------------------------
# ['probEall', 'weightEall', 'probIE', 'weightIE', 'probLengthConst', 'stimWeight'] [0.10354001770388188, 0.0036092833764708103, 0.2508599933514288, 0.0009974259160493246, 153.46893939485597, 0.05765704538247857]
# set probEall=0.10354001770388188
# set weightEall=0.0036092833764708103
# set probIE=0.2508599933514288
# set weightIE=0.0009974259160493246
# set probLengthConst=153.46893939485597
# set stimWeight=0.05765704538247857
# Saving simConfig to ./complex/gen_0/gen_0_cand_2_cfg.json ...
# --------------------------------------------------------------------------------
# ['probEall', 'weightEall', 'probIE', 'weightIE', 'probLengthConst', 'stimWeight'] [0.07724488376688435, 0.004721968102920533, 0.4758869445853113, 0.0009389807644835065, 126.91245259875824, 0.11160914442290285]
# set probEall=0.07724488376688435
# set weightEall=0.004721968102920533
# set probIE=0.4758869445853113
# set weightIE=0.0009389807644835065
# set probLengthConst=126.91245259875824
# set stimWeight=0.11160914442290285
# Saving simConfig to ./complex/gen_0/gen_0_cand_3_cfg.json ...
# --------------------------------------------------------------------------------
# ['probEall', 'weightEall', 'probIE', 'weightIE', 'probLengthConst', 'stimWeight'] [0.0843731879765797, 0.0052619971686475725, 0.44337656564971034, 0.0006162401307115975, 121.02646328178714, 0.13853480883793695]
# set probEall=0.0843731879765797
# set weightEall=0.0052619971686475725
# set probIE=0.44337656564971034
# set weightIE=0.0006162401307115975
# set probLengthConst=121.02646328178714
# set stimWeight=0.13853480883793695
# Saving simConfig to ./complex/gen_0/gen_0_cand_4_cfg.json ...
# --------------------------------------------------------------------------------
# ['probEall', 'weightEall', 'probIE', 'weightIE', 'probLengthConst', 'stimWeight'] [0.1499863431696175, 0.0037226978295311092, 0.22553515237113442, 0.0007742575922020229, 183.79570022928087, 0.1006140269607545]
# set probEall=0.1499863431696175
# set weightEall=0.0037226978295311092
# set probIE=0.22553515237113442
# set weightIE=0.0007742575922020229
# set probLengthConst=183.79570022928087
# set stimWeight=0.1006140269607545
# Saving simConfig to ./complex/gen_0/gen_0_cand_5_cfg.json ...
# --------------------------------------------------------------------------------
#
# Job in rank id:  0.0
# nrniv init.py simConfig=./complex/gen_0/gen_0_cand_0_cfg.json netParams=./complex/complex_netParams.py
#
# Job in rank id:  0.0
# nrniv init.py simConfig=./complex/gen_0/gen_0_cand_1_cfg.json netParams=./complex/complex_netParams.py
#
# Job in rank id:  0.0
# nrniv init.py simConfig=./complex/gen_0/gen_0_cand_2_cfg.json netParams=./complex/complex_netParams.py
#
# Job in rank id:  0.0
# nrniv init.py simConfig=./complex/gen_0/gen_0_cand_3_cfg.json netParams=./complex/complex_netParams.py
#
# Job in rank id:  0.0
# nrniv init.py simConfig=./complex/gen_0/gen_0_cand_4_cfg.json netParams=./complex/complex_netParams.py
#
# Job in rank id:  0.0
# nrniv init.py simConfig=./complex/gen_0/gen_0_cand_5_cfg.json netParams=./complex/complex_netParams.py
# Waiting for jobs from generation 0/4 ...
# There was an exception evaluating candidate 0:
#  'E2'
# There was an exception evaluating candidate 1:
#  'E2'
# There was an exception evaluating candidate 2:
#  'E2'
# There was an exception evaluating candidate 3:
#  'E2'
# There was an exception evaluating candidate 4:
#  'E2'
# There was an exception evaluating candidate 5:
#  'E2'
# completed: 0
# There was an exception evaluating candidate 0:
#  'E2'
# There was an exception evaluating candidate 1:
#  'E2'
# There was an exception evaluating candidate 2:
#  'E2'
# There was an exception evaluating candidate 3:
#  'E2'
# There was an exception evaluating candidate 4:
#  'E2'
# There was an exception evaluating candidate 5:
#  'E2'
# completed: 0
# There was an exception evaluating candidate 0:
#  'E2'
# There was an exception evaluating candidate 1:
#  'E2'
# There was an exception evaluating candidate 2:
#  'E2'
# There was an exception evaluating candidate 3:
#  'E2'
# There was an exception evaluating candidate 4:
#  'E2'
# There was an exception evaluating candidate 5:
#  'E2'
# completed: 0
# There was an exception evaluating candidate 0:
#  'E2'
# There was an exception evaluating candidate 1:
#  'E2'
# There was an exception evaluating candidate 2:
#  'E2'
# There was an exception evaluating candidate 3:
#  'E2'
# There was an exception evaluating candidate 4:
#  'E2'
# There was an exception evaluating candidate 5:
#  'E2'
# completed: 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 batch.run()
#
# File ~/miniconda3/envs/mycondaenv/lib/python3.11/site-packages/netpyne/batch/batch.py:247, in Batch.run(self)
#     243 # -------------------------------------------------------------------------------
#     244 # Evolutionary optimization
#     245 # -------------------------------------------------------------------------------
#     246 elif self.method == 'evol':
# --> 247     evolOptim(self, pc)
#     249 # -------------------------------------------------------------------------------
#     250 # Adaptive Stochastic Descent (ASD) optimization
#     251 # -------------------------------------------------------------------------------
#     252 elif self.method == 'asd':
#
# File ~/miniconda3/envs/mycondaenv/lib/python3.11/site-packages/netpyne/batch/evol.py:211, in evolOptim(batch, pc)
#     208     ngen += 1
#     209     return evaluator(batch, candidates, args, ngen, pc, **kwargs)
# --> 211 final_pop = ea.evolve(
#     212     generator=generator,
#     213     evaluator=func,
#     214     bounder=EC.Bounder(kwargs['lower_bound'], kwargs['upper_bound']),
#     215     logger=logger,
#     216     **kwargs
#     217 )
#     219 # close file
#     220 stats_file.close()
#
# File ~/miniconda3/envs/mycondaenv/lib/python3.11/site-packages/inspyred/ec/ec.py:439, in EvolutionaryComputation.evolve(self, generator, evaluator, pop_size, seeds, maximize, bounder, **args)
#     437     i += 1
#     438 self.logger.debug('evaluating initial population')
# --> 439 initial_fit = evaluator(candidates=initial_cs, args=self._kwargs)
#     441 for cs, fit in zip(initial_cs, initial_fit):
#     442     if fit is not None:
#
# File ~/miniconda3/envs/mycondaenv/lib/python3.11/site-packages/netpyne/batch/evol.py:209, in evolOptim.<locals>.func(candidates, args)
#     207 global ngen
#     208 ngen += 1
# --> 209 return evaluator(batch, candidates, args, ngen, pc, **kwargs)
#
# File ~/miniconda3/envs/mycondaenv/lib/python3.11/site-packages/netpyne/batch/utils.py:573, in evaluator(batch, candidates, args, ngen, pc, **kwargs)
#     571             except:
#     572                 pass
# --> 573     sleep(args.get('time_sleep', 1))
#     574 # kill all processes
#     575 if type == 'mpi_bulletin':
#
# KeyboardInterrupt:

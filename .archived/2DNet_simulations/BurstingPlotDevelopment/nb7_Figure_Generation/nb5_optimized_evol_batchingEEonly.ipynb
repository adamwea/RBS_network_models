# %%
## Initialize ##
# !pip install inspyred
import os
import pickle
import json
import shutil
# As needed, reset cwd to jupyter notebook location
nb5_path = ("/mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/batch_run_files/")
if os.getcwd() != nb5_path:
    os.chdir(nb5_path)

## USER INPUT REQUIRED ##
## Edit the following parameters as needed ##
## Edit params in the batch_run_files folder as needed (with care) ##
#Evol Batch Config Params
'''
BATCH RUN FOLDER
'''
#Prepare Batch_Run_Folder and Initial Files

output_path = nb5_path.replace('batch_run_files', 'output')
run_name = '24-3-24_5sec_EEsearch' ### Change this to a unique name for the batch run
run_path = output_path + run_name
overwrite_run = False #True will overwrite any existing run with the same name
continue_ = True #True will continue from the last generation of the run
#make sure batch_run_path does not exist. Avoid overwriting data from any Run
#overwrite_run = True #comment out later, this is for debugging
if continue_ is False:
    assert overwrite_run or not os.path.exists(run_path), f"Run {run_path} already exists. Set overwrite_run to True to overwrite."
if overwrite_run and os.path.exists(run_path):    
    shutil.rmtree(run_path)

# Create a directory to save the batch files
if not os.path.exists(run_path):
    os.makedirs(run_path)

'''
BATCH CONFIG
'''
import json

# Create a dictionary with the given variables and their values
pop_per_core = 15
core_num = 3
pop_size = pop_per_core * core_num
#duration_seconds = 5
batch_config_options = {
    "run_path": run_path,
    'batchLabel': os.path.basename(run_path),
    "method": "evol",
    "core_num": core_num,
    "nodes": 1,
    #"pop_per_core": 1,
    #"duration_seconds": 5,
    "pop_size": pop_size,
    "max_generations": 2000,
    "time_sleep": 10, #seconds
    "maxiter_wait": 6*40, #6itersx10sec/itersx30sec/min = 30 minutes per gen?
    "skip": True
}

# Write the dictionary to a JSON file
with open("batch_config_options.json", "w") as f:
    json.dump(batch_config_options, f)

'''
PARAMS
'''
# Create a directory to save the batch files
from netpyne import specs
from param_space import get_param_space, get_param_space_excite_only

## Prepare Parameter Space for Batch Run ##
duration_seconds = 5
#params = get_param_space(duration_seconds)
params = get_param_space_excite_only(duration_seconds)
param_space = params.copy()
with open(f'{run_path}/param_space.pickle', 'wb') as handle:
    pickle.dump(params, handle, protocol=pickle.HIGHEST_PROTOCOL)
#Also save as Json for easy reading
filename = f'{run_path}/param_space.json'
with open(filename, 'w') as file:
    json.dump(params, file, indent=4)


##cleanup
from batch_run_files.aw_batch_tools import move_btr_files
move_btr_files() #move any btr files to btr subfolder in batch_run_files

##print
from pprint import pprint
print("run_name: ", run_name)
print("output_path: ", output_path)
print("run_path: ", run_path)
print("overwrite_run: ", overwrite_run)
print("run_path: ", batch_config_options.get("run_path"))
print("pop_size: ", batch_config_options.get("pop_size"))
print("core_num: ", batch_config_options.get("core_num"))
print("nodes_per_core: ", batch_config_options.get("nodes"))
print("pop_per_core: ", batch_config_options.get("pop_per_core"))
print("duration_seconds: ", duration_seconds)
print("max_generations: ", batch_config_options.get("max_generations"))
print("time_sleep: ", batch_config_options.get("time_sleep"))
print("maxiter_wait: ", batch_config_options.get("maxiter_wait"))
print("skip: ", batch_config_options.get("skip"))
# Out:
# Requirement already satisfied: inspyred in /home/adam/miniconda3/envs/mycondaenv/lib/python3.11/site-packages (1.0.2)
# Requirement already satisfied: Click>=6.0 in /home/adam/miniconda3/envs/mycondaenv/lib/python3.11/site-packages (from inspyred) (8.1.6)
# Requirement already satisfied: numpy in /home/adam/miniconda3/envs/mycondaenv/lib/python3.11/site-packages (from inspyred) (1.26.4)
#  Could not create
# Saving netParams to const_netParams.json ...
# .btr files successfully moved.
# run_name:  24-3-24_5sec_EEsearch
# output_path:  /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/
# run_path:  /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-24_5sec_EEsearch
# overwrite_run:  False
# run_path:  /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-24_5sec_EEsearch
# pop_size:  45
# core_num:  3
# nodes_per_core:  1
# pop_per_core:  None
# duration_seconds:  5
# max_generations:  2000
# time_sleep:  10
# maxiter_wait:  240
# skip:  True

# %%
## Run Batch ##
import subprocess
from pprint import pprint
import pickle

# Define the command
cores = batch_config_options['core_num'] 
command = f"mpiexec -np {cores} nrniv -mpi batchRun.py"

# Run the command
debug = False
skip = False
if debug:
    from batch_run_files.batchRun import batchRun, get_batch_config

    #Limit batching for debugging
    core_num = 1
    max_generations = 1
    pop_size = 4
    batch_config_options['core_num'] = core_num
    batch_config_options['max_generations'] = max_generations
    batch_config_options['pop_size'] = pop_size
    # Write the dictionary to a JSON file
    with open("batch_config_options.json", "w") as f:
        json.dump(batch_config_options, f)
    
    batch_config = get_batch_config(batch_config_options = batch_config_options)
    # Load the dictionary from the JSON file
    # with open('batch_config.pickle', 'rb') as f:
    #     batch_config = pickle.load(f)
    assert 'method' in batch_config, 'method must be specified in batch_config'
    assert 'skip' in batch_config['runCfg'], 'skip must be specified in batch_config'
    assert 'batchLabel' in batch_config, 'batchLabel must be specified in batch_config'
    #after batch_config is loaded, delete it, there's a copy in the batch_run_path
    # #os.remove('batch_config.pickle')
    
    batchRun(
        batchLabel = batch_config_options['batchLabel'], 
        #method = 'grid', 
        method = 'evol',
        skip = False,
        batch_config = batch_config,
        ) 
else:
    print(command + '\n')
    jobName = f"{run_path}/evol_batchRun"
    process = subprocess.Popen(command.split(' '), stdout=open(jobName + '.run', 'w'), stderr=open(jobName + '.err', 'w'))
    # Get the output and errors, if any
    stdout, stderr = process.communicate()
    # Print the output
    if stdout: pprint(stdout)
    # Print the errors
    if stderr: pprint(stderr)
# Out:
# mpiexec -np 3 nrniv -mpi batchRun.py
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 49
#      47 process = subprocess.Popen(command.split(' '), stdout=open(jobName + '.run', 'w'), stderr=open(jobName + '.err', 'w'))
#      48 # Get the output and errors, if any
# ---> 49 stdout, stderr = process.communicate()
#      50 # Print the output
#      51 if stdout: pprint(stdout)
#
# File ~/miniconda3/envs/mycondaenv/lib/python3.11/subprocess.py:1201, in Popen.communicate(self, input, timeout)
#    1199         stderr = self.stderr.read()
#    1200         self.stderr.close()
# -> 1201     self.wait()
#    1202 else:
#    1203     if timeout is not None:
#
# File ~/miniconda3/envs/mycondaenv/lib/python3.11/subprocess.py:1264, in Popen.wait(self, timeout)
#    1262     endtime = _time() + timeout
#    1263 try:
# -> 1264     return self._wait(timeout=timeout)
#    1265 except KeyboardInterrupt:
#    1266     # https://bugs.python.org/issue25942
#    1267     # The first keyboard interrupt waits briefly for the child to
#    1268     # exit under the common assumption that it also received the ^C
#    1269     # generated SIGINT and will exit rapidly.
#    1270     if timeout is not None:
#
# File ~/miniconda3/envs/mycondaenv/lib/python3.11/subprocess.py:2046, in Popen._wait(self, timeout)
#    2044 if self.returncode is not None:
#    2045     break  # Another thread waited.
# -> 2046 (pid, sts) = self._try_wait(0)
#    2047 # Check the pid and loop as waitpid has been known to
#    2048 # return 0 even without WNOHANG in odd situations.
#    2049 # http://bugs.python.org/issue14396.
#    2050 if pid == self.pid:
#
# File ~/miniconda3/envs/mycondaenv/lib/python3.11/subprocess.py:2004, in Popen._try_wait(self, wait_flags)
#    2002 """All callers to this function MUST hold self._waitpid_lock."""
#    2003 try:
# -> 2004     (pid, sts) = os.waitpid(self.pid, wait_flags)
#    2005 except ChildProcessError:
#    2006     # This happens if SIGCLD is set to be ignored or waiting
#    2007     # for child processes has otherwise been disabled for our
#    2008     # process.  This child is dead, we can't get the status.
#    2009     pid = self.pid
#
# KeyboardInterrupt:

# %%
## Prepare Folder for Roy
import shutil
import os
import fnmatch

#output_path = '/mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.0_optimizing_75-25/output'
output_path = '/mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output'
reports_path = '/mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports'
#reports_path = '/mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.0_optimizing_75-25/reports'
overwrite = False

#walk through output_path, find all .svg and .png files, copy to new folder
for root, dirs, files in os.walk(output_path):
    if '.archive' in root: continue
    for file in files:
        report_file_types = ['.svg', '.png', '.pdf', '.csv', '.run', '.err', '.json', '.log']
        image_file_types = ['.svg', '.png'] 
        info_file_types = ['.pdf', 
                           #'.csv', 
                           '.run', '.err', '.json', '.log'] 
        if file.endswith(tuple(report_file_types)):
            file_path = os.path.join(root, file)
            new_path = file_path.replace(output_path, reports_path)
            new_dir = os.path.dirname(new_path)

            if file.endswith(tuple(info_file_types)):
               # Split the file path into directories
                directories = file_path.split(os.sep)
                # Check if any directory matches the pattern "gen_*"
                if any(fnmatch.fnmatch(dir, 'gen_*') for dir in directories):
                    continue  # Skip info files in gen folders
                new_dir = os.path.join(new_dir, 'batch_run_files')
                new_path = os.path.join(new_dir, file)
            
            #If file name contains "param_summary_row", copy to the grandparent folder instead
            if 'param_summary_row.png' in file:
                new_dir = os.path.dirname(new_dir)
                new_dir = os.path.dirname(new_dir)
                new_path = os.path.join(new_dir, file)
            
            #If file name contains ".csv"
            if '.csv' in file:
                #new_dir = os.path.dirname(new_dir)
                new_path = os.path.join(new_dir, file)

            #make sure the new directory exists
            if not os.path.exists(new_dir):
                os.makedirs(new_dir)
            if not os.path.exists(new_path) and overwrite is False:
                shutil.copy(file_path, new_path)
                print(f'Copied {file_path} to {new_path}')
            elif overwrite is True:
                shutil.copy(file_path, new_path)
                print(f'Copied {file_path} to {new_path}')
# Out:
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/evol_batchRun.run to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/batch_run_files/evol_batchRun.run
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/param_space.json to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/batch_run_files/param_space.json
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/evol_batchRun.err to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/batch_run_files/evol_batchRun.err
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/24-3-23_5sec_EEsearch_stats.csv to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/24-3-23_5sec_EEsearch_stats.csv
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/inspyred.log to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/batch_run_files/inspyred.log
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/24-3-23_5sec_EEsearch_stats_indiv.csv to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/24-3-23_5sec_EEsearch_stats_indiv.csv
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/24-3-23_5sec_EEsearch_batch.json to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/batch_run_files/24-3-23_5sec_EEsearch_batch.json
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_3/gen_1_cand_3__plot_2Dnet.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_3/gen_1_cand_3__plot_2Dnet.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_3/gen_1_cand_3__sample_trace_E.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_3/gen_1_cand_3__sample_trace_E.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_3/gen_1_cand_3__plot_2Dnet.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_3/gen_1_cand_3__plot_2Dnet.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_3/gen_1_cand_3__conn_matrix.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_3/gen_1_cand_3__conn_matrix.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_3/gen_1_cand_3__sample_trace_E.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_3/gen_1_cand_3__sample_trace_E.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_3/gen_1_cand_3__param_summary_row.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1_cand_3__param_summary_row.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_3/gen_1_cand_3__network_activity_def.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_3/gen_1_cand_3__network_activity_def.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_3/gen_1_cand_3__network_activity_def.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_3/gen_1_cand_3__network_activity_def.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_3/gen_1_cand_3__raster.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_3/gen_1_cand_3__raster.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_3/gen_1_cand_3__param_summary_row.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_3/gen_1_cand_3__param_summary_row.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_3/gen_1_cand_3__raster.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_3/gen_1_cand_3__raster.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_3/gen_1_cand_3__conn_matrix.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_3/gen_1_cand_3__conn_matrix.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_69/gen_1_cand_69__plot_2Dnet.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_69/gen_1_cand_69__plot_2Dnet.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_69/gen_1_cand_69__raster.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_69/gen_1_cand_69__raster.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_69/gen_1_cand_69__sample_trace_E.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_69/gen_1_cand_69__sample_trace_E.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_69/gen_1_cand_69__network_activity_def.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_69/gen_1_cand_69__network_activity_def.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_69/gen_1_cand_69__plot_2Dnet.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_69/gen_1_cand_69__plot_2Dnet.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_69/gen_1_cand_69__network_activity_def.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_69/gen_1_cand_69__network_activity_def.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_69/gen_1_cand_69__conn_matrix.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_69/gen_1_cand_69__conn_matrix.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_69/gen_1_cand_69__param_summary_row.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_69/gen_1_cand_69__param_summary_row.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_69/gen_1_cand_69__conn_matrix.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_69/gen_1_cand_69__conn_matrix.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_69/gen_1_cand_69__raster.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_69/gen_1_cand_69__raster.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_69/gen_1_cand_69__param_summary_row.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1_cand_69__param_summary_row.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_69/gen_1_cand_69__sample_trace_E.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_69/gen_1_cand_69__sample_trace_E.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_63/gen_1_cand_63__raster.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_63/gen_1_cand_63__raster.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_63/gen_1_cand_63__sample_trace_E.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_63/gen_1_cand_63__sample_trace_E.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_63/gen_1_cand_63__param_summary_row.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_63/gen_1_cand_63__param_summary_row.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_63/gen_1_cand_63__param_summary_row.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1_cand_63__param_summary_row.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_63/gen_1_cand_63__network_activity_def.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_63/gen_1_cand_63__network_activity_def.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_63/gen_1_cand_63__network_activity_def.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_63/gen_1_cand_63__network_activity_def.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_63/gen_1_cand_63__raster.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_63/gen_1_cand_63__raster.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_63/gen_1_cand_63__sample_trace_E.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_63/gen_1_cand_63__sample_trace_E.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_63/gen_1_cand_63__conn_matrix.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_63/gen_1_cand_63__conn_matrix.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_63/gen_1_cand_63__plot_2Dnet.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_63/gen_1_cand_63__plot_2Dnet.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_63/gen_1_cand_63__plot_2Dnet.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_63/gen_1_cand_63__plot_2Dnet.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_63/gen_1_cand_63__conn_matrix.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_63/gen_1_cand_63__conn_matrix.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_27/gen_1_cand_27__network_activity_def.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_27/gen_1_cand_27__network_activity_def.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_27/gen_1_cand_27__conn_matrix.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_27/gen_1_cand_27__conn_matrix.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_27/gen_1_cand_27__conn_matrix.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_27/gen_1_cand_27__conn_matrix.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_27/gen_1_cand_27__network_activity_def.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_27/gen_1_cand_27__network_activity_def.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_27/gen_1_cand_27__raster.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_27/gen_1_cand_27__raster.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_27/gen_1_cand_27__sample_trace_E.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_27/gen_1_cand_27__sample_trace_E.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_27/gen_1_cand_27__sample_trace_E.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_27/gen_1_cand_27__sample_trace_E.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_27/gen_1_cand_27__plot_2Dnet.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_27/gen_1_cand_27__plot_2Dnet.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_27/gen_1_cand_27__plot_2Dnet.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_27/gen_1_cand_27__plot_2Dnet.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_27/gen_1_cand_27__param_summary_row.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_27/gen_1_cand_27__param_summary_row.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_27/gen_1_cand_27__param_summary_row.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1_cand_27__param_summary_row.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_27/gen_1_cand_27__raster.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_27/gen_1_cand_27__raster.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_29/gen_1_cand_29__param_summary_row.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1_cand_29__param_summary_row.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_29/gen_1_cand_29__plot_2Dnet.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_29/gen_1_cand_29__plot_2Dnet.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_29/gen_1_cand_29__sample_trace_E.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_29/gen_1_cand_29__sample_trace_E.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_29/gen_1_cand_29__raster.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_29/gen_1_cand_29__raster.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_29/gen_1_cand_29__raster.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_29/gen_1_cand_29__raster.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_29/gen_1_cand_29__conn_matrix.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_29/gen_1_cand_29__conn_matrix.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_29/gen_1_cand_29__network_activity_def.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_29/gen_1_cand_29__network_activity_def.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_29/gen_1_cand_29__conn_matrix.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_29/gen_1_cand_29__conn_matrix.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_29/gen_1_cand_29__plot_2Dnet.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_29/gen_1_cand_29__plot_2Dnet.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_29/gen_1_cand_29__param_summary_row.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_29/gen_1_cand_29__param_summary_row.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_29/gen_1_cand_29__network_activity_def.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_29/gen_1_cand_29__network_activity_def.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_29/gen_1_cand_29__sample_trace_E.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_29/gen_1_cand_29__sample_trace_E.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_34/gen_1_cand_34__param_summary_row.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1_cand_34__param_summary_row.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_34/gen_1_cand_34__network_activity_def.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_34/gen_1_cand_34__network_activity_def.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_34/gen_1_cand_34__conn_matrix.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_34/gen_1_cand_34__conn_matrix.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_34/gen_1_cand_34__plot_2Dnet.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_34/gen_1_cand_34__plot_2Dnet.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_34/gen_1_cand_34__plot_2Dnet.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_34/gen_1_cand_34__plot_2Dnet.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_34/gen_1_cand_34__param_summary_row.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_34/gen_1_cand_34__param_summary_row.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_34/gen_1_cand_34__sample_trace_E.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_34/gen_1_cand_34__sample_trace_E.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_34/gen_1_cand_34__raster.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_34/gen_1_cand_34__raster.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_34/gen_1_cand_34__raster.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_34/gen_1_cand_34__raster.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_34/gen_1_cand_34__conn_matrix.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_34/gen_1_cand_34__conn_matrix.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_34/gen_1_cand_34__network_activity_def.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_34/gen_1_cand_34__network_activity_def.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_34/gen_1_cand_34__sample_trace_E.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_1/gen_1_cand_34/gen_1_cand_34__sample_trace_E.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_3/gen_3_cand_6/gen_3_cand_6__param_summary_row.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_3_cand_6__param_summary_row.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_3/gen_3_cand_6/gen_3_cand_6__conn_matrix.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_3/gen_3_cand_6/gen_3_cand_6__conn_matrix.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_3/gen_3_cand_6/gen_3_cand_6__raster.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_3/gen_3_cand_6/gen_3_cand_6__raster.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_3/gen_3_cand_6/gen_3_cand_6__sample_trace_E.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_3/gen_3_cand_6/gen_3_cand_6__sample_trace_E.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_3/gen_3_cand_6/gen_3_cand_6__sample_trace_E.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_3/gen_3_cand_6/gen_3_cand_6__sample_trace_E.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_3/gen_3_cand_6/gen_3_cand_6__network_activity_def.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_3/gen_3_cand_6/gen_3_cand_6__network_activity_def.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_3/gen_3_cand_6/gen_3_cand_6__conn_matrix.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_3/gen_3_cand_6/gen_3_cand_6__conn_matrix.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_3/gen_3_cand_6/gen_3_cand_6__plot_2Dnet.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_3/gen_3_cand_6/gen_3_cand_6__plot_2Dnet.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_3/gen_3_cand_6/gen_3_cand_6__param_summary_row.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_3/gen_3_cand_6/gen_3_cand_6__param_summary_row.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_3/gen_3_cand_6/gen_3_cand_6__raster.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_3/gen_3_cand_6/gen_3_cand_6__raster.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_3/gen_3_cand_6/gen_3_cand_6__plot_2Dnet.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_3/gen_3_cand_6/gen_3_cand_6__plot_2Dnet.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_3/gen_3_cand_6/gen_3_cand_6__network_activity_def.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_3/gen_3_cand_6/gen_3_cand_6__network_activity_def.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_3/gen_3_cand_45/gen_3_cand_45__plot_2Dnet.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_3/gen_3_cand_45/gen_3_cand_45__plot_2Dnet.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_3/gen_3_cand_45/gen_3_cand_45__plot_2Dnet.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_3/gen_3_cand_45/gen_3_cand_45__plot_2Dnet.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_3/gen_3_cand_45/gen_3_cand_45__param_summary_row.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_3_cand_45__param_summary_row.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_3/gen_3_cand_45/gen_3_cand_45__sample_trace_E.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_3/gen_3_cand_45/gen_3_cand_45__sample_trace_E.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_3/gen_3_cand_45/gen_3_cand_45__param_summary_row.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_3/gen_3_cand_45/gen_3_cand_45__param_summary_row.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_3/gen_3_cand_45/gen_3_cand_45__conn_matrix.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_3/gen_3_cand_45/gen_3_cand_45__conn_matrix.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_3/gen_3_cand_45/gen_3_cand_45__raster.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_3/gen_3_cand_45/gen_3_cand_45__raster.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_3/gen_3_cand_45/gen_3_cand_45__network_activity_def.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_3/gen_3_cand_45/gen_3_cand_45__network_activity_def.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_3/gen_3_cand_45/gen_3_cand_45__sample_trace_E.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_3/gen_3_cand_45/gen_3_cand_45__sample_trace_E.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_3/gen_3_cand_45/gen_3_cand_45__conn_matrix.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_3/gen_3_cand_45/gen_3_cand_45__conn_matrix.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_3/gen_3_cand_45/gen_3_cand_45__network_activity_def.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_3/gen_3_cand_45/gen_3_cand_45__network_activity_def.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_3/gen_3_cand_45/gen_3_cand_45__raster.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_3/gen_3_cand_45/gen_3_cand_45__raster.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_3/gen_3_cand_4/gen_3_cand_4__network_activity_def.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_3/gen_3_cand_4/gen_3_cand_4__network_activity_def.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_3/gen_3_cand_4/gen_3_cand_4__raster.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_3/gen_3_cand_4/gen_3_cand_4__raster.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_3/gen_3_cand_4/gen_3_cand_4__raster.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_3/gen_3_cand_4/gen_3_cand_4__raster.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_3/gen_3_cand_4/gen_3_cand_4__param_summary_row.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_3/gen_3_cand_4/gen_3_cand_4__param_summary_row.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_3/gen_3_cand_4/gen_3_cand_4__plot_2Dnet.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_3/gen_3_cand_4/gen_3_cand_4__plot_2Dnet.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_3/gen_3_cand_4/gen_3_cand_4__sample_trace_E.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_3/gen_3_cand_4/gen_3_cand_4__sample_trace_E.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_3/gen_3_cand_4/gen_3_cand_4__plot_2Dnet.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_3/gen_3_cand_4/gen_3_cand_4__plot_2Dnet.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_3/gen_3_cand_4/gen_3_cand_4__network_activity_def.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_3/gen_3_cand_4/gen_3_cand_4__network_activity_def.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_3/gen_3_cand_4/gen_3_cand_4__conn_matrix.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_3/gen_3_cand_4/gen_3_cand_4__conn_matrix.png
# ...
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_68/gen_2_cand_68__network_activity_def.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_68/gen_2_cand_68__network_activity_def.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_60/gen_2_cand_60__raster.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_60/gen_2_cand_60__raster.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_60/gen_2_cand_60__param_summary_row.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_2_cand_60__param_summary_row.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_60/gen_2_cand_60__sample_trace_E.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_60/gen_2_cand_60__sample_trace_E.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_60/gen_2_cand_60__raster.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_60/gen_2_cand_60__raster.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_60/gen_2_cand_60__network_activity_def.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_60/gen_2_cand_60__network_activity_def.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_60/gen_2_cand_60__conn_matrix.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_60/gen_2_cand_60__conn_matrix.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_60/gen_2_cand_60__param_summary_row.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_60/gen_2_cand_60__param_summary_row.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_60/gen_2_cand_60__plot_2Dnet.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_60/gen_2_cand_60__plot_2Dnet.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_60/gen_2_cand_60__plot_2Dnet.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_60/gen_2_cand_60__plot_2Dnet.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_60/gen_2_cand_60__conn_matrix.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_60/gen_2_cand_60__conn_matrix.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_60/gen_2_cand_60__network_activity_def.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_60/gen_2_cand_60__network_activity_def.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_60/gen_2_cand_60__sample_trace_E.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_60/gen_2_cand_60__sample_trace_E.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_13/gen_2_cand_13__raster.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_13/gen_2_cand_13__raster.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_13/gen_2_cand_13__raster.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_13/gen_2_cand_13__raster.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_13/gen_2_cand_13__param_summary_row.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_2_cand_13__param_summary_row.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_13/gen_2_cand_13__conn_matrix.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_13/gen_2_cand_13__conn_matrix.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_13/gen_2_cand_13__plot_2Dnet.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_13/gen_2_cand_13__plot_2Dnet.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_13/gen_2_cand_13__network_activity_def.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_13/gen_2_cand_13__network_activity_def.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_13/gen_2_cand_13__param_summary_row.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_13/gen_2_cand_13__param_summary_row.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_13/gen_2_cand_13__sample_trace_E.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_13/gen_2_cand_13__sample_trace_E.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_13/gen_2_cand_13__sample_trace_E.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_13/gen_2_cand_13__sample_trace_E.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_13/gen_2_cand_13__plot_2Dnet.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_13/gen_2_cand_13__plot_2Dnet.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_13/gen_2_cand_13__conn_matrix.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_13/gen_2_cand_13__conn_matrix.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_13/gen_2_cand_13__network_activity_def.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_13/gen_2_cand_13__network_activity_def.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_28/gen_2_cand_28__conn_matrix.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_28/gen_2_cand_28__conn_matrix.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_28/gen_2_cand_28__plot_2Dnet.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_28/gen_2_cand_28__plot_2Dnet.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_28/gen_2_cand_28__network_activity_def.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_28/gen_2_cand_28__network_activity_def.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_28/gen_2_cand_28__network_activity_def.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_28/gen_2_cand_28__network_activity_def.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_28/gen_2_cand_28__raster.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_28/gen_2_cand_28__raster.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_28/gen_2_cand_28__sample_trace_E.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_28/gen_2_cand_28__sample_trace_E.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_28/gen_2_cand_28__param_summary_row.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_28/gen_2_cand_28__param_summary_row.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_28/gen_2_cand_28__param_summary_row.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_2_cand_28__param_summary_row.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_28/gen_2_cand_28__conn_matrix.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_28/gen_2_cand_28__conn_matrix.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_28/gen_2_cand_28__sample_trace_E.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_28/gen_2_cand_28__sample_trace_E.png
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_28/gen_2_cand_28__plot_2Dnet.svg to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_28/gen_2_cand_28__plot_2Dnet.svg
# Copied /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/output/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_28/gen_2_cand_28__raster.png to /mnt/disk15tb/adam/git_workspace/netpyne_2DNetworkSimulations/2DNet_simulations/BurstingPlotDevelopment/nb5.1_optimizing_EEonly/reports/24-3-23_5sec_EEsearch/gen_2/gen_2_cand_28/gen_2_cand_28__raster.png
